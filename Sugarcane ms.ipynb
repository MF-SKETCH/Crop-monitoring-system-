# %%
import matplotlib.pyplot as plt
import random
n_days = 7
temperature = []
moisture = []
rainfall = []
growth_list = []

# %%
for day in range(1, n_days + 1):
    tem = random.randint(28, 35) 
    moist = random.randint(50, 70)
    rain = random.randint(0, 20)
    growth = random.randint(5, 15)
    temperature.append(tem)
    moisture.append(moist)
    rainfall.append(rain)
    growth_list.append(height)
    print(f"Day {day}: Temperature: {tem}°C, Moisture: {moist}%, Rainfall: {rain}mm, Growth: {growth}cm")
# Out:
# Day 1: Temperature: 31°C, Moisture: 53%, Rainfall: 19mm, Growth: 10cm
# Day 2: Temperature: 32°C, Moisture: 55%, Rainfall: 6mm, Growth: 15cm
# Day 3: Temperature: 33°C, Moisture: 55%, Rainfall: 5mm, Growth: 8cm
# Day 4: Temperature: 35°C, Moisture: 64%, Rainfall: 6mm, Growth: 9cm
# Day 5: Temperature: 32°C, Moisture: 53%, Rainfall: 9mm, Growth: 14cm
# Day 6: Temperature: 31°C, Moisture: 64%, Rainfall: 8mm, Growth: 5cm
# Day 7: Temperature: 32°C, Moisture: 60%, Rainfall: 3mm, Growth: 6cm

# %%
# X-axis days
days = list(range(1, n_days + 1))

# Graph lines
plt.plot(days, temperature, label="Temperature (°C)")
plt.plot(days, moisture, label="Soil Moisture (%)")
plt.plot(days, rainfall, label="Rainfall (mm)")
plt.plot(days, growth_list, label="Sugarcane Height (cm)", linestyle="--", marker="o")

plt.xlabel("Days")
plt.ylabel("Values")
plt.title("Sugarcane Crop Monitoring (Random Data)")
plt.legend()
plt.grid(True)
plt.show()
